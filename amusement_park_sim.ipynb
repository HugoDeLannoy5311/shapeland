# %% [markdown]
# # Notebook Intentions
#
# The purpose of this notebook is to simulate an amusement park.

# %%
from park import Park
from behavior_reference import BEHAVIOR_ARCHETYPE_PARAMETERS

# %% [markdown]
# ### Book Keeping
#
#     - Version: dictates the location performance graphs are stored
#     - Verbosity: controls much information is displayed during a simulation, increase to show more info
#     - Show Plots: controls whether park plots are displayed in this notebook
#     - RNG Seed: seeds random number generators to enforce identical results across runs/machines

# %%
VERSION = "20K All FP - MIKE"
VERBOSITY = 0
SHOW_PLOTS = True
RNG_SEED = 5

# %% [markdown]
# ## Park
#
# The park contains Agents, Attractions and Activities.
#
# - Total Daily Agents: dictates how many agents visit the park within a day
# - Hourly Percent: dictates what percentage of Total Daily Agents visits the park at each hour
# - Perfect Arrivals: enforces that the exact amount of Total Daily Agents arrives during the day
# - Expedited Pass Ability Percent: percent of agents aware of expeditied passes
# - Expedited Threshold: acceptable queue wait time length before searching for an expedited pass
# - Expedited Limit: total number of expedited pass an agent can hold at any given time

# %%
TOTAL_DAILY_AGENTS = 2000
PERFECT_ARRIVALS = True
HOURLY_PERCENT = {
    "10:00 AM": 10,
    "11:00 AM": 20,
    "12:00 AM": 17,
    "3:00 PM": 20,
    "4:00 PM": 15,
    "5:00 PM": 10,
    "6:00 PM": 1,
    "7:00 PM": 5,
    "8:00 PM": 1,
    "9:00 PM": 1,
    "10:00 PM": 0,
    "11:00 PM": 0,
    "12:00 PM": 0
}
EXP_ABILITY_PCT = 1.0
EXP_THRESHOLD = 1
EXP_LIMIT = 3

# %% [markdown]
# ## Agents
#
# The park is populated by agents. Agents visit attractions and activities. They make decisions about where to go based on their preferences, the popularity of attractions and activities and waiting times. Each Agent has a behavioral archetype.
#
# - Ride Enthusiast: wants to stay for a long time, go on as many attractions as possible, doesn't want to visit activites, doesn't mind waiting
# - Ride Favorer: wants to go on a lot of attractions, but will vists activites occasionally, will wait for a while in a queue
# - Park Tourer: wants to stay for a long time and wants to see attractions and activities equally, reasonable about wait times
# - Park Visitor: doesn't want to stay long and wants to see attractions and activities equally, inpatient about wait times
# - Activity Favorer: doesn't want to stay long and prefers activities, reasonable about wait times
# - Activity Enthusiast: wants to visit a lot of activities, reasonable about wait times
#
# Archetypes can be tweaked and new archetypes can be added in `behavior_reference.py`.
#
# - Agent Archetype Distribution: dictates the probability an agent will have a particular behavioral archetype

# %%
AGENT_ARCHETYPE_DISTRIBUTION = {
    "ride_enthusiast": 10,
    "ride_favorer": 15,
    "park_tourer": 25,
    "park_visitor": 30,
    "activity_favorer": 15,
    "activity_enthusiast": 5,
}

# %% [markdown]
# ## Attractions
#
# Attractions are essentially rides within a park.
#
# - Attractions: list of dictionaries that describe the attractions within the park
#     - Name: name of the attraction
#     - Run Time: How long the attraction take to run, in minutes
#     - Capacity: Maximium number of agents that can be on the attraction during a run
#     - Popularity: Value from 1-10 that describes how popular an attraction is with respect to other attractions
#     - Expedited Queue: Dictates whether the attraction has an expedited queue or not
#     - Expedited Queue Ratio: Dictates what percentage of attraction capacity is devoted to members of the expedited queue
#     - Child Eligible: Dictates whether children can ride the attraction
#     - Adult Eligible: Dictates whether adults can ride the attraction

# %%
ATTRACTIONS = [
    {
        "name": "Alpha",
        "run_time": 10,
        "hourly_throughput": 3000,
        "popularity": 10,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": True,
    },
    {
        "name": "Beta",
        "run_time": 5,
        "hourly_throughput": 2400,
        "popularity": 9,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": True,
    },
    {
        "name": "Gamma",
        "run_time": 15,
        "hourly_throughput": 2000,
        "popularity": 8,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": True,
    },
    {
        "name": "Delta",
        "run_time": 5,
        "hourly_throughput": 1200,
        "popularity": 7,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": False,
    },
    {
        "name": "Epsilon",
        "run_time": 10,
        "hourly_throughput": 2000,
        "popularity": 6,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": False,
        "adult_eligible": True,
    },
    {
        "name": "Zeta",
        "run_time": 6,
        "hourly_throughput": 2000,
        "popularity": 5,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": False,
    },
    {
        "name": "Eta",
        "run_time": 12,
        "hourly_throughput": 2400,
        "popularity": 4,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": False,
        "adult_eligible": True,
    }
]

# %% [markdown]
# ## Activities
# Activities are everything to do within the park that isn't an attraction.
#
# - Activities: list of dictionaries that describe activities within the park
#     - Name: name of the activity
#     - Popularity: Value from 1-10 that describes how popular an activity is with respect to other activities
#     - Mean Time: The expected time agents will spend at an activity

# %%
ACTIVITIES = [
    {
      "name": "sightseeing",
      "popularity": 5,
      "mean_time": 5
    },
    {
      "name": "show",
      "popularity": 5,
      "mean_time": 30
    },
    {
      "name": "merchandise",
      "popularity": 5,
      "mean_time": 30
    },
    {
      "name": "food",
      "popularity": 5,
      "mean_time": 45
    }
  ]

# %% [markdown]
# ## Plots
#
# Set the Y limit of plots

# %%
PLOT_RANGE = {
    "Attraction Queue Length": 1800,
    "Attraction Wait Time": 200,
    "Attraction Expedited Queue Length": 6000,
    "Attraction Expedited Wait Time": 500,
    "Activity Vistors": 20000,
    "Approximate Agent Distribution (General)": 1.0,
    "Approximate Agent Distribution (Specific)": 1.0,
    "Attraction Average Wait Times": 120,
    "Agent Attractions Histogram": 1.0,
    "Attraction Total Visits": 46000,
    "Expedited Pass Distribution": 150000,
    "Age Class Distribution": 20000,
}

# %% [markdown]
# ## Simulation
#
# Run the simulation here.

# %%
# Initialize Park
RNG_SEED = 5

park = Park(
    attraction_list=ATTRACTIONS,
    activity_list=ACTIVITIES,
    plot_range=PLOT_RANGE,
    random_seed=RNG_SEED,
    version=VERSION,
    verbosity=VERBOSITY
)

# Build Arrivals

park.generate_arrival_schedule(
    arrival_seed=HOURLY_PERCENT, 
    total_daily_agents=TOTAL_DAILY_AGENTS, 
    perfect_arrivals=PERFECT_ARRIVALS,
)

# Build Agents
park.generate_agents(
    behavior_archetype_distribution=AGENT_ARCHETYPE_DISTRIBUTION,
    exp_ability_pct=EXP_ABILITY_PCT,
    exp_wait_threshold=EXP_THRESHOLD,
    exp_limit=EXP_LIMIT
)

# Build Attractions + Activities
park.generate_attractions()
park.generate_activities()

# Pass Time
for _ in range(len(HOURLY_PERCENT.keys()) * 60):
    park.step()

# Save Parameters of Current Run
sim_parameters = {
    "VERSION": VERSION,
    "VERBOSITY": VERBOSITY,
    "SHOW_PLOTS": SHOW_PLOTS,
    "RNG_SEED": RNG_SEED,
    "TOTAL_DAILY_AGENTS": TOTAL_DAILY_AGENTS,
    "PERFECT_ARRIVALS": PERFECT_ARRIVALS,
    "HOURLY_PERCENT": HOURLY_PERCENT,
    "EXP_ABILITY_PCT": EXP_ABILITY_PCT,
    "EXP_THRESHOLD": EXP_THRESHOLD,
    "EXP_LIMIT": EXP_LIMIT,
    "AGENT_ARCHETYPE_DISTRIBUTION": AGENT_ARCHETYPE_DISTRIBUTION,
    "ATTRACTIONS": ATTRACTIONS,
    "ACTIVITIES": ACTIVITIES,
    "BEHAVIOR_ARCHETYPE_PARAMETERS": BEHAVIOR_ARCHETYPE_PARAMETERS,
}
park.write_data_to_file(
    data=sim_parameters, 
    output_file_path=f"{VERSION}/parameters", 
    output_file_format="json"
)

# Store + Print Data
park.make_plots(show=SHOW_PLOTS)
park.print_logs(N = 5)
#park.print_logs(selected_agent_ids = [778])
# Out:
# +--------------+---------------------+--------------+
# | Attraction   |   Average Wait Time | Queue Type   |
# |--------------+---------------------+--------------|
# | Eta          |                5.51 | Expedited    |
# | Zeta         |                2.50 | Expedited    |
# | Epsilon      |                4.51 | Expedited    |
# | Delta        |                2.00 | Expedited    |
# | Gamma        |                7.01 | Expedited    |
# | Beta         |                2.00 | Expedited    |
# | Alpha        |                4.51 | Expedited    |
# | Eta          |                5.51 | Standby      |
# | Zeta         |                2.50 | Standby      |
# | Epsilon      |                4.51 | Standby      |
# | Delta        |                2.00 | Standby      |
# | Gamma        |                7.01 | Standby      |
# | Beta         |                2.00 | Standby      |
# | Alpha        |                4.51 | Standby      |
# +--------------+---------------------+--------------+
# +----------+-----------------------------+
# | Metric   |   Total Attractions Visited |
# |----------+-----------------------------|
# | count    |                     2000.00 |
# | mean     |                        9.73 |
# | std      |                       12.02 |
# | min      |                        0.00 |
# | 25%      |                        4.00 |
# | 50%      |                        5.00 |
# | 75%      |                        7.00 |
# | max      |                       69.00 |
# +----------+-----------------------------+
# c:\Users\nick.roumimper\OneDrive - Stichting Hogeschool Utrecht\Documents\- 2023-2024 - SIMPROG\casus-shapeland\park.py:336: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(data=df, x=x, y=y, hue=hue, ci=None, estimator=estimator)
# +--------------+----------+
# | Attraction   |   Visits |
# |--------------+----------|
# | Alpha        |     4519 |
# | Beta         |     4425 |
# | Delta        |     3591 |
# | Epsilon      |        0 |
# | Eta          |        0 |
# | Gamma        |     4009 |
# | Zeta         |     2914 |
# +--------------+----------+
# +--------------------+----------------+-------------+
# | Expedited Passes   |   Total Passes | Type        |
# |--------------------+----------------+-------------|
# |                    |          15239 | Distributed |
# |                    |          15097 | Redeemed    |
# +--------------------+----------------+-------------+
# +-------------+----------+----------------+
# | Age Class   |   Agents | Type           |
# |-------------+----------+----------------|
# |             |     2000 | No Adult Rides |
# |             |        0 | No Child Rides |
# |             |        0 | No Preference  |
# +-------------+----------+----------------+
# Agent ID: 1275
# Agent Archetype: park_tourer
# Agent arrived at park at time 229. Agent visited the activity sightseeing at time 229. Agent exited the activity sightseeing at time 230. Agent visited the activity show at time 231. Agent exited the activity show at time 238. Agent visited the activity show at time 239. Agent exited the activity show at time 246. Agent picked up an expedited pass for Alpha at time 247. The estimated expedited queue wait time is 3 minutes. Agent visited the activity food at time 248. Agent exited the activity food at time 250. Agent boarded Alpha and redeemed their expedited queue pass at time 250. Agent exited Alpha at time 260. Agent visited the activity merchandise at time 261. Agent exited the activity merchandise at time 268. Agent visited the activity show at time 269. Agent exited the activity show at time 276. Agent visited the activity merchandise at time 277. Agent exited the activity merchandise at time 284. Agent entered queue for Delta at time 285. Agent boarded Delta at time 285. Agent exited Delta at time 290. Agent visited the activity sightseeing at time 291. Agent exited the activity sightseeing at time 292. Agent picked up an expedited pass for Beta at time 293. The estimated expedited queue wait time is 2 minutes. Agent visited the activity show at time 294. Agent exited the activity show at time 295. Agent boarded Beta and redeemed their expedited queue pass at time 295. Agent exited Beta at time 300. Agent visited the activity sightseeing at time 301. Agent exited the activity sightseeing at time 302. Agent visited the activity sightseeing at time 303. Agent exited the activity sightseeing at time 304. Agent visited the activity sightseeing at time 305. Agent exited the activity sightseeing at time 306. Agent visited the activity show at time 307. Agent exited the activity show at time 314. Agent visited the activity merchandise at time 315. Agent exited the activity merchandise at time 322. Agent visited the activity show at time 323. Agent exited the activity show at time 330. Agent visited the activity food at time 331. Agent exited the activity food at time 342. Agent visited the activity show at time 343. Agent exited the activity show at time 350. Agent visited the activity show at time 351. Agent exited the activity show at time 358. Agent visited the activity show at time 359. Agent exited the activity show at time 366. Agent visited the activity food at time 367. Agent exited the activity food at time 378. Agent picked up an expedited pass for Zeta at time 379. The estimated expedited queue wait time is 5 minutes. Agent visited the activity food at time 380. Agent exited the activity food at time 384. Agent boarded Zeta and redeemed their expedited queue pass at time 384. Agent exited Zeta at time 390. Agent visited the activity show at time 391. Agent exited the activity show at time 398. Agent picked up an expedited pass for Gamma at time 399. The estimated expedited queue wait time is 6 minutes. Agent visited the activity sightseeing at time 400. Agent exited the activity sightseeing at time 401. Agent visited the activity sightseeing at time 402. Agent exited the activity sightseeing at time 403. Agent visited the activity show at time 404. Agent exited the activity show at time 405. Agent boarded Gamma and redeemed their expedited queue pass at time 405. Agent exited Gamma at time 420. Agent visited the activity food at time 421. Agent exited the activity food at time 432. Agent visited the activity show at time 433. Agent exited the activity show at time 440. Agent visited the activity merchandise at time 441. Agent exited the activity merchandise at time 448. Agent visited the activity merchandise at time 449. Agent exited the activity merchandise at time 456. Agent visited the activity sightseeing at time 457. Agent exited the activity sightseeing at time 458. Agent visited the activity food at time 459. Agent exited the activity food at time 470. Agent visited the activity sightseeing at time 471. Agent  ...
#
# Agent ID: 523
# Agent Archetype: activity_favorer
# Agent arrived at park at time 110. Agent visited the activity merchandise at time 110. Agent exited the activity merchandise at time 140. Agent visited the activity food at time 141. Agent exited the activity food at time 187. Agent visited the activity food at time 188. Agent exited the activity food at time 234. Agent entered queue for Beta at time 235. Agent boarded Beta at time 235. Agent exited Beta at time 240. Agent visited the activity sightseeing at time 241. Agent exited the activity sightseeing at time 246. Agent visited the activity sightseeing at time 247. Agent exited the activity sightseeing at time 252. Agent visited the activity merchandise at time 253. Agent exited the activity merchandise at time 283. Agent picked up an expedited pass for Alpha at time 284. The estimated expedited queue wait time is 6 minutes. Agent visited the activity show at time 285. Agent exited the activity show at time 290. Agent boarded Alpha and redeemed their expedited queue pass at time 290. Agent exited Alpha at time 300. Agent visited the activity food at time 301. Agent exited the activity food at time 347. Agent visited the activity sightseeing at time 348. Agent exited the activity sightseeing at time 353. Agent visited the activity show at time 354. Agent exited the activity show at time 384. Agent left park at 385.
#
# Agent ID: 1519
# Agent Archetype: ride_favorer
# Agent arrived at park at time 270. Agent entered queue for Delta at time 270. Agent boarded Delta at time 270. Agent exited Delta at time 275. Agent visited the activity sightseeing at time 276. Agent exited the activity sightseeing at time 281. Agent visited the activity sightseeing at time 282. Agent exited the activity sightseeing at time 287. Agent picked up an expedited pass for Gamma at time 288. The estimated expedited queue wait time is 12 minutes. Agent visited the activity show at time 289. Agent exited the activity show at time 300. Agent boarded Gamma and redeemed their expedited queue pass at time 300. Agent exited Gamma at time 315. Agent visited the activity show at time 316. Agent exited the activity show at time 351. Agent picked up an expedited pass for Gamma at time 352. The estimated expedited queue wait time is 8 minutes. Agent picked up an expedited pass for Delta at time 353. The estimated expedited queue wait time is 2 minutes. Agent picked up an expedited pass for Alpha at time 354. The estimated expedited queue wait time is 6 minutes. Agent visited the activity merchandise at time 355. Agent exited the activity merchandise at time 355. Agent boarded Delta and redeemed their expedited queue pass at time 355. Agent exited Delta at time 360. Agent boarded Gamma and redeemed their expedited queue pass at time 360. Agent boarded Alpha and redeemed their expedited queue pass at time 360. Agent exited Alpha at time 370. Agent visited the activity food at time 371. Agent exited Gamma at time 375. Agent picked up an expedited pass for Alpha at time 376. The estimated expedited queue wait time is 4 minutes. Agent picked up an expedited pass for Gamma at time 377. The estimated expedited queue wait time is 13 minutes. Agent visited the activity show at time 378. Agent exited the activity show at time 380. Agent boarded Alpha and redeemed their expedited queue pass at time 380. Agent boarded Gamma and redeemed their expedited queue pass at time 390. Agent exited Alpha at time 390. Agent visited the activity show at time 391. Agent exited Gamma at time 405. Agent visited the activity show at time 406. Agent exited the activity food at time 424. Agent visited the activity food at time 425. Agent exited the activity show at time 426. Agent picked up an expedited pass for Delta at time 427. The estimated expedited queue wait time is 3 minutes. Agent visited the activity merchandise at time 428. Agent exited the activity merchandise at time 430. Agent boarded Delta and redeemed their expedited queue pass at time 430. Agent exited Delta at time 435. Agent visited the activity sightseeing at time 436. Agent exited the activity sightseeing at time 441. Agent exited the activity show at time 441. Agent picked up an expedited pass for Alpha at time 442. The estimated expedited queue wait time is 8 minutes. Agent visited the activity sightseeing at time 443. Agent exited the activity sightseeing at time 448. Agent visited the activity merchandise at time 449. Agent exited the activity merchandise at time 450. Agent boarded Alpha and redeemed their expedited queue pass at time 450. Agent exited Alpha at time 460. Agent picked up an expedited pass for Beta at time 461. The estimated expedited queue wait time is 4 minutes. Agent visited the activity merchandise at time 462. Agent exited the activity merchandise at time 465. Agent boarded Beta and redeemed their expedited queue pass at time 465. Agent exited Beta at time 470. Agent picked up an expedited pass for Alpha at time 471. The estimated expedited queue wait time is 9 minutes. Agent visited the activity show at time 472. Agent exited the activity food at time 478. Agent visited the activity sightseeing at time 479. Agent exited the activity sightseeing at time 480. Agent boarded Alpha and redeemed their expedited queue pass at time 480. Agent exited the activity show at time 480. Agent visited the activity show at time 481. Agent exited Alpha at time 490. Agent picked u ...
#
# Agent ID: 734
# Agent Archetype: park_visitor
# Agent arrived at park at time 141. Agent picked up an expedited pass for Delta at time 141. The estimated expedited queue wait time is 4 minutes. Agent visited the activity show at time 142. Agent exited the activity show at time 145. Agent boarded Delta and redeemed their expedited queue pass at time 145. Agent exited Delta at time 150. Agent picked up an expedited pass for Gamma at time 151. The estimated expedited queue wait time is 14 minutes. Agent visited the activity food at time 152. Agent exited the activity food at time 165. Agent boarded Gamma and redeemed their expedited queue pass at time 165. Agent exited Gamma at time 180. Agent visited the activity show at time 181. Agent exited the activity show at time 210. Agent picked up an expedited pass for Alpha at time 211. The estimated expedited queue wait time is 9 minutes. Agent visited the activity sightseeing at time 212. Agent exited the activity sightseeing at time 216. Agent visited the activity merchandise at time 217. Agent exited the activity merchandise at time 220. Agent boarded Alpha and redeemed their expedited queue pass at time 220. Agent exited Alpha at time 230. Agent picked up an expedited pass for Beta at time 231. The estimated expedited queue wait time is 4 minutes. Agent visited the activity show at time 232. Agent exited the activity show at time 235. Agent boarded Beta and redeemed their expedited queue pass at time 235. Agent exited Beta at time 240. Agent visited the activity food at time 241. Agent exited the activity food at time 285. Agent visited the activity food at time 286. Agent exited the activity food at time 330. Agent visited the activity sightseeing at time 331. Agent exited the activity sightseeing at time 335. Agent visited the activity sightseeing at time 336. Agent exited the activity sightseeing at time 340. Agent entered queue for Zeta at time 341. Agent boarded Zeta at time 342. Agent exited Zeta at time 348. Agent visited the activity show at time 349. Agent exited the activity show at time 378. Agent visited the activity food at time 379. Agent exited the activity food at time 423. Agent visited the activity merchandise at time 424. Agent exited the activity merchandise at time 453. Agent visited the activity show at time 454. Agent exited the activity show at time 483. Agent visited the activity show at time 484. Agent exited the activity show at time 513. Agent visited the activity show at time 514. Agent exited the activity show at time 543. Agent visited the activity food at time 544. Agent exited the activity food at time 588. Agent left park at 589.
#
# Agent ID: 1628
# Agent Archetype: park_visitor
# Agent arrived at park at time 293. Agent visited the activity sightseeing at time 293. Agent exited the activity sightseeing at time 297. Agent visited the activity sightseeing at time 298. Agent exited the activity sightseeing at time 302. Agent picked up an expedited pass for Beta at time 303. The estimated expedited queue wait time is 2 minutes. Agent picked up an expedited pass for Zeta at time 304. The estimated expedited queue wait time is 2 minutes. Agent picked up an expedited pass for Gamma at time 305. The estimated expedited queue wait time is 10 minutes. Agent boarded Beta and redeemed their expedited queue pass at time 305. Agent boarded Zeta and redeemed their expedited queue pass at time 306. Agent exited Beta at time 310. Agent visited the activity merchandise at time 311. Agent exited Zeta at time 312. Agent visited the activity food at time 313. Agent exited the activity food at time 315. Agent boarded Gamma and redeemed their expedited queue pass at time 315. Agent exited the activity merchandise at time 315. Agent visited the activity sightseeing at time 316. Agent exited the activity sightseeing at time 320. Agent visited the activity sightseeing at time 321. Agent exited the activity sightseeing at time 325. Agent picked up an expedited pass for Delta at time 326. The estimated expedited queue wait time is 4 minutes. Agent picked up an expedited pass for Alpha at time 327. The estimated expedited queue wait time is 3 minutes. Agent picked up an expedited pass for Gamma at time 328. The estimated expedited queue wait time is 2 minutes. Agent visited the activity food at time 329. Agent exited the activity food at time 330. Agent boarded Delta and redeemed their expedited queue pass at time 330. Agent exited Gamma at time 330. Agent boarded Gamma and redeemed their expedited queue pass at time 330. Agent boarded Alpha and redeemed their expedited queue pass at time 330. Agent exited Delta at time 335. Agent picked up an expedited pass for Alpha at time 336. The estimated expedited queue wait time is 4 minutes. Agent visited the activity food at time 337. Agent exited Alpha at time 340. Agent boarded Alpha and redeemed their expedited queue pass at time 340. Agent exited the activity food at time 340. Agent visited the activity merchandise at time 341. Agent exited Gamma at time 345. Agent visited the activity sightseeing at time 346. Agent exited Alpha at time 350. Agent exited the activity sightseeing at time 350. Agent visited the activity sightseeing at time 351. Agent exited the activity sightseeing at time 355. Agent visited the activity food at time 356. Agent exited the activity merchandise at time 370. Agent visited the activity show at time 371. Agent exited the activity food at time 399. Agent visited the activity sightseeing at time 400. Agent exited the activity show at time 400. Agent visited the activity merchandise at time 401. Agent exited the activity sightseeing at time 404. Agent visited the activity sightseeing at time 405. Agent exited the activity sightseeing at time 409. Agent visited the activity food at time 410. Agent exited the activity merchandise at time 430. Agent visited the activity sightseeing at time 431. Agent exited the activity sightseeing at time 435. Agent visited the activity merchandise at time 436. Agent exited the activity food at time 453. Agent visited the activity show at time 454. Agent exited the activity merchandise at time 465. Agent visited the activity merchandise at time 466. Agent exited the activity show at time 483. Agent visited the activity sightseeing at time 484. Agent exited the activity sightseeing at time 488. Agent visited the activity merchandise at time 489. Agent exited the activity merchandise at time 495. Agent visited the activity sightseeing at time 496. Agent exited the activity sightseeing at time 500. Agent visited the activity merchandise at time 501. Agent exited the activity merchandise at time 518. Agent visited the activity show  ...
